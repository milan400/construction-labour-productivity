# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/humandetectdataset/README.dataset.txt
# /kaggle/input/humandetectdataset/README.roboflow.txt
# /kaggle/input/humandetectdataset/data.yaml
# /kaggle/input/humandetectdataset/valid/labels/one_709_jpg.rf.1951b256751c2de7a17a23449d746dc9.txt
# /kaggle/input/humandetectdataset/valid/labels/one_2560_jpg.rf.235495a2adbacecc1b51de6fd9f8dde0.txt
# /kaggle/input/humandetectdataset/valid/labels/one_2_jpg.rf.7b539f4df71417244933217b8a6cf61b.txt
# /kaggle/input/humandetectdataset/valid/labels/one_2278_jpg.rf.91abe4999acdda8f984500e1b6ed4b78.txt
# /kaggle/input/humandetectdataset/valid/labels/one_3097_jpg.rf.5d562105af1b26bcfdfaf8cf2f240d1b.txt
# /kaggle/input/humandetectdataset/valid/labels/one_1902_jpg.rf.e6ef299b1def2cc192f7e3c385e72134.txt
# /kaggle/input/humandetectdataset/valid/labels/one_2809_jpg.rf.f5a3c2215e00bd214e44eae8c346560e.txt
# /kaggle/input/humandetectdataset/valid/labels/one_2658_jpg.rf.df5c0a2396ae20592835669edee7b933.txt
# ...

# %%
# !pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.185 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6411.6/8062.4 GB disk)

# %%
# !pip install roboflow
from roboflow import Roboflow

'''
rf = Roboflow(api_key="RL0IkPKFsjbLSK1SUaGu")
project = rf.workspace("titulacin").project("person-detection-9a6mk")
version = project.version(16)
dataset = version.download("yolov11")
'''
# Out:
# ...
# '\nrf = Roboflow(api_key="RL0IkPKFsjbLSK1SUaGu")\nproject = rf.workspace("titulacin").project("person-detection-9a6mk")\nversion = project.version(16)\ndataset = version.download("yolov11")\n'

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=/kaggle/input/humandetectdataset/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# ...
# Ultralytics 8.3.185 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls runs/detect/train

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'runs/detect/train/confusion_matrix.png', width=600)

# %%
IPyImage(filename=f'runs/detect/train/confusion_matrix_normalized.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'runs/detect/train/PR_curve.png', width=600)

# %%
IPyImage(filename=f'runs/detect/train/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'runs/detect/train/val_batch1_pred.jpg', width=600)

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob(f'runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")
